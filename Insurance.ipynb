# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

# %%
Insurance_data = pd.read_csv("D:/Data/1/Course Materials/Data/insurance.csv")

# %%
Insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
Insurance_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
Insurance_data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.boxenplot(x=Insurance_data["age"])
# Out:
# <Axes: xlabel='age'>

# %%
sns.histplot(x=Insurance_data["age"])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(x=Insurance_data["bmi"])
# Out:
# <Axes: xlabel='bmi', ylabel='Count'>

# %%
Insurance_data["smoker"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
Insurance_data["region"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
Insurance_data["children"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
Insurance_data["sex"].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
sns.heatmap(Insurance_data.corr(numeric_only=True), annot=True,vmin=-1,vmax=1,cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.scatterplot(Insurance_data,x="age",y="charges",hue="smoker")
# Out:
# <Axes: xlabel='age', ylabel='charges'>

# %%
Insurance_data.groupby("smoker")["charges"].mean().plot.bar()
# Out:
# <Axes: xlabel='smoker'>

# %%
sns.scatterplot(Insurance_data,x="age",y="bmi")
# Out:
# <Axes: xlabel='age', ylabel='bmi'>

# %%
Insurance_data.groupby("smoker")["bmi"].mean().plot.bar()
# Out:
# <Axes: xlabel='smoker'>

# %%
Insurance_data.groupby("smoker")["age"].mean().plot.bar()
# Out:
# <Axes: xlabel='smoker'>

# %%
sns.pairplot(Insurance_data)

# %%
sns.lmplot(Insurance_data,x="bmi",y="charges",hue="smoker")

# %%
sns.pairplot(Insurance_data,corner=True,diag_kind="kde")

# %%
computer_data = pd.read_csv("D:/Data/1/Course Materials/Data/computers.csv")

# %%
computer_data.head()
# Out:
#    price  speed   hd  ram  screen  cd multi premium  ads  trend
# 0   1499     25   80    4      14  no    no     yes   94      1
# 1   1795     33   85    2      14  no    no     yes   94      1
# 2   1595     25  170    4      15  no    no     yes   94      1
# 3   1849     25  170    8      14  no    no      no   94      1
# 4   3295     33  340   16      14  no    no     yes   94      1

# %%
computer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6259 entries, 0 to 6258
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   price    6259 non-null   int64
#  1   speed    6259 non-null   int64
#  2   hd       6259 non-null   int64
#  3   ram      6259 non-null   int64
#  4   screen   6259 non-null   int64
#  5   cd       6259 non-null   object
#  6   multi    6259 non-null   object
#  7   premium  6259 non-null   object
#  8   ads      6259 non-null   int64
#  9   trend    6259 non-null   int64
# dtypes: int64(7), object(3)
# memory usage: 489.1+ KB

# %%
computer_data.describe
# Out:
# <bound method NDFrame.describe of       price  speed    hd  ram  screen   cd multi premium  ads  trend
# 0      1499     25    80    4      14   no    no     yes   94      1
# 1      1795     33    85    2      14   no    no     yes   94      1
# 2      1595     25   170    4      15   no    no     yes   94      1
# 3      1849     25   170    8      14   no    no      no   94      1
# 4      3295     33   340   16      14   no    no     yes   94      1
# ...     ...    ...   ...  ...     ...  ...   ...     ...  ...    ...
# 6254   1690    100   528    8      15   no    no     yes   39     35
# 6255   2223     66   850   16      15  yes   yes     yes   39     35
# 6256   2654    100  1200   24      15  yes    no     yes   39     35
# 6257   2195    100   850   16      15  yes    no     yes   39     35
# 6258   2490    100   850   16      17  yes    no     yes   39     35
#
# [6259 rows x 10 columns]>

# %%
sns.histplot(computer_data["price"])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.histplot(computer_data["price"])

# %%
sns.boxplot(x = computer_data["price"])
# Out:
# <Axes: xlabel='price'>

# %%
sns.boxplot(x = computer_data["ram"])
# Out:
# <Axes: xlabel='ram'>

# %%
sns.histplot(x = computer_data["speed"])
# Out:
# <Axes: xlabel='speed', ylabel='Count'>

# %%
columns = ["speed","ram","price"]
data = computer_data
fig , ax = plt.subplots(len(columns),layout = "tight")

for col,ax in zip(columns , ax.flat):
    sns.histplot(data = data , x = col , ax = ax)
    ax.set_title(f"Histogram of {col}")

# %%
sns.heatmap(computer_data.corr(numeric_only=True), annot=True,vmin=-1,vmax=1,cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.scatterplot(computer_data,x="speed",y="price")
# Out:
# <Axes: xlabel='speed', ylabel='price'>

# %%
sns.lmplot(computer_data,x="ram",y="price",hue="premium")

# %%
sns.pairplot(computer_data,corner=True,diag_kind="kde")

# %%
Dimond_data = pd.read_csv("D:/Data/1/Course Materials/Data/Diamonds Prices2022.csv")

# %%
Dimond_data.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
Dimond_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53943 entries, 0 to 53942
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53943 non-null  float64
#  1   cut      53943 non-null  object
#  2   color    53943 non-null  object
#  3   clarity  53943 non-null  object
#  4   depth    53943 non-null  float64
#  5   table    53943 non-null  float64
#  6   price    53943 non-null  int64
#  7   x        53943 non-null  float64
#  8   y        53943 non-null  float64
#  9   z        53943 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
Dimond_data.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53943.000000  53943.000000  53943.000000  53943.000000  53943.000000
# mean       0.797935     61.749322     57.457251   3932.734294      5.731158
# std        0.473999      1.432626      2.234549   3989.338447      1.121730
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53943.000000  53943.000000
# mean       5.734526      3.538730
# std        1.142103      0.705679
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
sns.histplot(Dimond_data["price"])
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.boxenplot(x = Dimond_data["price"])
# Out:
# <Axes: xlabel='price'>

# %%
sns.heatmap(Dimond_data.corr(numeric_only=True), annot=True,vmin=-1,vmax=1,cmap="coolwarm")
# Out:
# <Axes: >

# %%
sns.pairplot(Dimond_data,corner=True,diag_kind="kde")

# %%
x = Dimond_data["price"]
y = Dimond_data["carat"]

# %%
sm.OLS(y,x).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  carat   R-squared (uncentered):                   0.881
# Model:                            OLS   Adj. R-squared (uncentered):              0.881
# Method:                 Least Squares   F-statistic:                          4.004e+05
# Date:                Sun, 11 Feb 2024   Prob (F-statistic):                        0.00
# Time:                        11:49:51   Log-Likelihood:                         -15043.
# No. Observations:               53943   AIC:                                  3.009e+04
# Df Residuals:                   53942   BIC:                                  3.010e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...
